# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Github

# %%
# !git init intro_program
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/intro_program/.git/

# %%
# %cd intro_program/
# Out:
# /content/drive/MyDrive/Github/intro_program

# %%
print('hello Git!')
# Out:
# hello Git!

# %%
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)
